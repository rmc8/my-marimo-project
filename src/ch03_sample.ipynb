# %%
import polars as pl

df = pl.DataFrame(
    {
        "height": [160.1, 155.7, 172.9, 149.3, 183.1],
        "weight": [55.3, 51.2, 66.9, 49.2, 70.1],
    },
)
df.head()
# Out:
# shape: (5, 2)
# ┌────────┬────────┐
# │ height ┆ weight │
# │ ---    ┆ ---    │
# │ f64    ┆ f64    │
# ╞════════╪════════╡
# │ 160.1  ┆ 55.3   │
# │ 155.7  ┆ 51.2   │
# │ 172.9  ┆ 66.9   │
# │ 149.3  ┆ 49.2   │
# │ 183.1  ┆ 70.1   │
# └────────┴────────┘
